# %%
import pandas as pd
import numpy as np
import tweepy

# %%
#Primero definimos las claves de acceso para usar la librería Tweepy para extraer distintos Tweets

consumer_key = 'mjYn2dDYH4fUi5YxNKgJxfc7e'
consumer_secret = 'SWjGHnxEkMHdJs71f8eKIGOllHFcRiS1SJaQd3LKMfMijgXgK2'
access_token = '1453344661121257473-jvcjxIYrqoIK3LJ72mq7tPILX78Bfd'
access_token_secret = 'Gu2L7K9xVrCAKGV8xlYc3ZvM5E9u3WAdUoSiDm8WdZXXf'

"""Para conseguir las distintas claves de uso que solicita la librería podemos adquirirlas con nuestro usuario personal de Tweeter (X) 
ingresando desde la opciónd e developer para poder extraer datos justificando la finalidad"""

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit= True)

"""Para lograr una extracción de datos de Tweeter(X) es necesario poseer un acceso de privilegio específico, tal acceso se comenzó a solicitar luego de cambiar las políticas de la app de modo que se tuvo que recurrir a las evidencias en el reto propuesto"""

# %%
"""Para utilizar los datos de Tweets disponibles se los traslado de un archivo de texto a un json el cual podemos manipularlo con la librería Pandas"""
import json

with open('tweets.json', 'r', encoding='latin-1') as file:
    tweets = json.load(file)
print(json.dumps(tweets, indent=2))
# Out:
# [
#   {
#     "id": 1,
#     "texto": "La tecnolog\u00c3\u00ada de la realidad virtual est\u00c3\u00a1 revolucionando la forma en que experimentamos los videojuegos. #tecnolog\u00c3\u00ada #videojuegos",
#     "usuario": "gamers_unidos",
#     "hashtags": [
#       "tecnolog\u00c3\u00ada",
#       "videojuegos"
#     ],
#     "fecha": "2023-03-13 16:45:00",
#     "retweets": 23,
#     "favoritos": 87
#   },
#   {
#     "id": 2,
#     "texto": "Apple anuncia el lanzamiento de su nuevo iPhone 15 con c\u00c3\u00a1mara mejorada y pantalla OLED de 6,7 pulgadas. #Apple #iPhone15",
#     "usuario": "tech_news",
#     "hashtags": [
#       "Apple",
#       "iPhone15"
#     ],
#     "fecha": "2023-03-12 10:30:00",
#     "retweets": 234,
#     "favoritos": 1876
#   },
#   {
#     "id": 3,
#     "texto": "Google presenta su nuevo asistente virtual con inteligencia artificial que permite controlar el hogar desde el smartphone. #Google #hogarinteligente",
#     "usuario": "tech_guru",
# ...

# %%
"""Para luego transformarlo en un dataframe donde podemos analizar con más claridad el formato de los datos obtenidos"""
tweeters = pd.DataFrame(tweets)
"""Establecemos un parámetro para el índice a partir de la primer columna id """
tweeters.set_index('id', inplace=True)

# %%
"""Primero visualizamos las columnas para conocer como está estructurado el resultado"""
print(tweeters.columns)
"""Luego podemos especificar los distintos tipos de datos obtenidos"""
print(tweeters.info())
# Out:
# Index(['texto', 'usuario', 'hashtags', 'fecha', 'retweets', 'favoritos'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1 to 25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   texto      25 non-null     object
#  1   usuario    25 non-null     object
#  2   hashtags   25 non-null     object
#  3   fecha      25 non-null     object
#  4   retweets   25 non-null     int64
#  5   favoritos  25 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.4+ KB
# None

# %%
"""Con pandas también podesmos guardar para exportar el dataframe ya creado"""
# %store tweeters
# Out:
# Stored 'tweeters' (DataFrame)
